# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
#improted wanted libray

# %%
saphani=pd.read_csv('results.csv') #gatting csv values from your machine

# %%
saphani.head() #displaye you data  it frist display first 5 data
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
saphani.dtypes #checking data type
# Out:
# date          object
# home_team     object
# away_team     object
# home_score     int64
# away_score     int64
# tournament    object
# city          object
# country       object
# neutral         bool
# dtype: object

# %%
saphani.info() #checking null values if it is ther
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40839 entries, 0 to 40838
# Data columns (total 9 columns):
# date          40839 non-null object
# home_team     40839 non-null object
# away_team     40839 non-null object
# home_score    40839 non-null int64
# away_score    40839 non-null int64
# tournament    40839 non-null object
# city          40839 non-null object
# country       40839 non-null object
# neutral       40839 non-null bool
# dtypes: bool(1), int64(2), object(6)
# memory usage: 2.5+ MB

# %%
saphani.isnull().sum() #easys way of checking null value
# Out:
# date          0
# home_team     0
# away_team     0
# home_score    0
# away_score    0
# tournament    0
# city          0
# country       0
# neutral       0
# dtype: int64

# %%
sns.heatmap(saphani.corr())

# %%
saphani.corr()
# Out:
#             home_score  away_score   neutral
# home_score    1.000000   -0.133412 -0.031660
# away_score   -0.133412    1.000000  0.084335
# neutral      -0.031660    0.084335  1.000000

# %%
saphani.columns
# Out:
# Index(['date', 'home_team', 'away_team', 'home_score', 'away_score',
#        'tournament', 'city', 'country', 'neutral'],
#       dtype='object')

# %%
sns.pairplot(saphani)
# Out:
# /home/wecode/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:778: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
#   a, weights = _ravel_and_check_weights(a, weights)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py in _unsigned_subtract(a, b)
#     341     try:
# --> 342         dt = signed_to_unsigned[dt.type]
#     343     except KeyError:
#
# KeyError: <class 'numpy.bool_'>
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-3be5db03a074> in <module>
# ----> 1 sns.pairplot(saphani)
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, dropna, plot_kws, diag_kws, grid_kws, size)
#    2105     if grid.square_grid:
#    2106         if diag_kind == "hist":
# -> 2107             grid.map_diag(plt.hist, **diag_kws)
#    2108         elif diag_kind == "kde":
#    2109             diag_kws.setdefault("shade", True)
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py in map_diag(self, func, **kwargs)
#    1397                     color = fixed_color
#    1398
# -> 1399                 func(data_k, label=label_k, color=color, **kwargs)
#    1400
#    1401             self._clean_axis(ax)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, data, **kwargs)
#    2634         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2635         color=color, label=label, stacked=stacked, normed=normed,
# -> 2636         **({"data": data} if data is not None else {}), **kwargs)
#    2637
#    2638
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# -> 1589             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1590
#    1591         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, **kwargs)
#    6751             # this will automatically overwrite bins,
#    6752             # so that each histogram uses the same bins
# -> 6753             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6754             m = m.astype(float)  # causes problems later if it's an int
#    6755             if mlast is None:
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py in histogram(a, bins, range, normed, weights, density)
#     808
#     809         # Pre-compute histogram scaling factor
# --> 810         norm = n_equal_bins / _unsigned_subtract(last_edge, first_edge)
#     811
#     812         # We iterate over blocks here for two reasons: the first is that for
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py in _unsigned_subtract(a, b)
#     342         dt = signed_to_unsigned[dt.type]
#     343     except KeyError:
# --> 344         return np.subtract(a, b, dtype=dt)
#     345     else:
#     346         # we know the inputs are integers, and we are deliberately casting
#
# TypeError: numpy boolean subtract, the `-` operator, is deprecated, use the bitwise_xor, the `^` operator, or the logical_xor function instead.

# %%
saphani.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
saphani.sort_values('home_score',ascending=False).head()
# Out:
#              date  home_team       away_team  home_score  away_score  \
# 23781  2001-04-11  Australia  American Samoa          31           0
# 7893   1971-09-13     Tahiti    Cook Islands          30           0
# 10931  1979-08-30       Fiji        Kiribati          24           0
# 23778  2001-04-09  Australia           Tonga          22           0
# 28815  2006-11-24      Sápmi          Monaco          21           1
#
#                          tournament           city           country  neutral
# 23781  FIFA World Cup qualification  Coffs Harbour         Australia    False
# 7893            South Pacific Games        Papeete  French Polynesia    False
# 10931           South Pacific Games        Nausori              Fiji    False
# 23778  FIFA World Cup qualification  Coffs Harbour         Australia    False
# 28815                Viva World Cup         Hyères            France     True

# %%
saphani.sort_values('away_score',ascending=False).head()
# Out:
#              date       home_team         away_team  home_score  away_score  \
# 27350  2005-03-11            Guam       North Korea           0          21
# 14705  1987-12-15  American Samoa  Papua New Guinea           0          20
# 25671  2003-06-30            Sark     Isle of Wight           0          20
# 35998  2014-06-01          Darfur           Padania           0          20
# 12697  1983-08-22            Niue  Papua New Guinea           0          19
#
#                       tournament        city         country  neutral
# 27350          EAFF Championship      Taipei  Chinese Taipei     True
# 14705        South Pacific Games      Nouméa   New Caledonia     True
# 25671               Island Games  St. Martin        Guernsey     True
# 35998  CONIFA World Football Cup   Östersund          Sweden     True
# 12697        South Pacific Games        Apia   Western Samoa     True

# %%
saphani['total']=saphani.home_score + saphani.away_score

# %%
saphani.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral  total
# 0  Scotland    False      0
# 1   England    False      6
# 2  Scotland    False      3
# 3   England    False      4
# 4  Scotland    False      3

# %%
saphani.sort_values('total',ascending=False).head()
# Out:
#              date  home_team       away_team  home_score  away_score  \
# 23781  2001-04-11  Australia  American Samoa          31           0
# 7893   1971-09-13     Tahiti    Cook Islands          30           0
# 10931  1979-08-30       Fiji        Kiribati          24           0
# 28815  2006-11-24      Sápmi          Monaco          21           1
# 23778  2001-04-09  Australia           Tonga          22           0
#
#                          tournament           city           country  neutral  \
# 23781  FIFA World Cup qualification  Coffs Harbour         Australia    False
# 7893            South Pacific Games        Papeete  French Polynesia    False
# 10931           South Pacific Games        Nausori              Fiji    False
# 28815                Viva World Cup         Hyères            France     True
# 23778  FIFA World Cup qualification  Coffs Harbour         Australia    False
#
#        total
# 23781     31
# 7893      30
# 10931     24
# 28815     22
# 23778     22
